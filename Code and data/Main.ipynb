# %%
import numpy as np
import pandas as pd

df=pd.read_csv("PLFS 2021-22 and 2022-23 V1-2.csv")
df.head()
# Out:
#   Quarter visit  Sector  State    fsu  sample_sg  SSSTRM  hh_no  month_survey  \
# 0      Q3    V1       1      9  10001          1       1      1             1
# 1      Q3    V1       1      9  10001          1       2      1             1
# 2      Q3    V1       1      9  10001          1       2      2             1
# 3      Q3    V1       1      9  10001          1       3      1             1
# 4      Q3    V1       1      9  10001          2       1      1             1
#
#    hh_size  ...  SEXm  SEXt  WPR_cws  UR_cws  LFPR_cws  Year  NCO_UPSS1  \
# 0        3  ...   1.0     1        1     0.0         1  2022        NaN
# 1        2  ...   1.0     1        1     0.0         1  2022        NaN
# 2        5  ...   2.0     2        0     NaN         0  2022        NaN
# 3        6  ...   1.0     1        0     1.0         1  2022        NaN
# 4        7  ...   1.0     1        1     0.0         1  2022        NaN
#
#    NCO_cws1  Selfmonth_cwsMis  Age1
# ...

# %%
# 3
# PLFS Data 2021-22 and 2022-23
# Coding Design
# S No Variable Name Variable Destription
# Quarter    Quarter   
# visit    Visit   
# Sector  Sector 
# State State/Ut Code
# fsu        FSU
# sample_sg    Sample Sg/Sb No.
# SSSTRM       Second Stage Stratum No.
# hh_no      Sample Household Number
# month_survey  Month of Survey
# hh_size    Household Size
# hh_type  Household Type
# rsn_sub_org_hh Reason for Substitution of original household
# religion   Religion
# social_group  Social Group
# hh_cons_exp  Household'S Usual Consumer Expenditure In A Month (Rs.)
# info_srn      Informant Serial no.
# NSS   Ns count for sector x stratum x substratum x sub-sample
# NSC     Ns count for sector x stratum x substratum
# MULT     Sub-sample wise Multiplier
# No_QR  Occurance of State x Sector x Stratum x SubStratum in 4 Quarters
# psn     Person Serial No.
# Reltn_to_head    Relationship To Head
# Sex Sex
# Age Age
# Marital_status Marital_status
# GE  General Educaion Level
# TE   Technical Educaion Level
# No_yrs_Formal No. of years in Formal Education
# current_atten Status of Current Attendance in Educational Institution
# VET Whether received any Vocational/Technical Training
# Usual_princ Status Code
# NIC_UPSS   Industry Code (NIC)
# NCO_UPSS   Occupation Code (NCO)
# Sub_act    Whether Engaged In Any Work In Subsidiary Capacity
# Usual_subs Status Code
# NIC_sub     Industry Code (NIC)
# NCO_sub   Occupation Code (NCO)
# a1 Status Code for activity 1
# a2     Industry Code (NIC) for activity 1
# a3   hours actuallly worked for activity 1 on 7 th day
# a4   wage earning for activity 1 on 7 th day
# a5   Status Code for activity 2
# a6      Industry Code (NIC) for activity 2
# a7  hours actuallly worked for activity 2 on 7 th day
# a8     wage earning for activity 2 on 7 th day
# a9    total hours actually worked on 7th day
# a10 hours available for aditional worked on 7th day
# a11    Status Code for activity 1
# a12     Industry Code (NIC) for activity 1
# a13    hours actuallly worked for activity 1 on 6 th day
# a14     wage earning for activity 1 on 7 th day
# a15     Status Code for activity 2
# a16   Industry Code (NIC) for activity 2
# a17    hours actuallly worked for activity 2 on 6 th day
# a18   wage earning for activity 2 on 6 th day
# a19     total hours actually worked on 6th day
# a20    hours available for aditional worked on 6th day
# a21    Status Code for activity 1
# a22   Industry Code (NIC) for activity 1
# a23  hours actuallly worked for activity 1 on5 th day
# a24  wage earning for activity 1 on 5 th day
# a25   Status Code for activity 2
# a26 Industry Code (NIC) for activity 2
# a27  hours actuallly worked for activity 2 on 5 th day
# a28 wage earning for activity 2 on 5 th day
# a29  total hours actually worked on 5th day
# a30   hours available for aditional worked on 5th day
# a31    Status Code for activity 1
# a32  Industry Code (NIC) for activity 1
# a33    hours actuallly worked for activity 1 on 4th day
# a34    wage earning for activity 1 on 4th day
# a35     Status Code for activity 2
# a36     Industry Code (NIC) for activity 2
# a37   hours actuallly worked for activity 2 on 4th day
# a38   wage earning for activity 2 on 4th day
# a39  total hours actually worked on 4th day
# a40  hours available for aditional worked on 4th day
# a41   Status Code for activity 1
# a42  Industry Code (NIC) for activity 1
# a43  hours actuallly worked for activity 1 on 3rd day
# a44   wage earning for activity 1 on 3rd day
# a45  Status Code for activity 2
# a46   Industry Code (NIC) for activity 2
# a47 hours actuallly worked for activity 2 on 3rd day
# a48   wage earning for activity 2 on 3 rd day
# a49    total hours actually worked on 3rd day
# a50 hours available for aditional worked on 3rd day
# a51  Status Code for activity 1
# a52  Industry Code (NIC) for activity 1
# a53 hours actuallly worked for activity 1 on 2nd day
# a54  wage earning for activity 1 on 2nd day
# a55    Status Code for activity 2
# a56 Industry Code (NIC) for activity 2
# a57   hours actuallly worked for activity 2 on 2nd day
# a58   wage earning for activity 2 on 2nd day
# a59 total hours actually worked on 2nd day
# a60  hours available for aditional worked on 2nd day
# a61  Status Code for activity 1
# a62   Industry Code (NIC) for activity 1
# a63 hours actuallly worked for activity 1 on 1st day
# a64   wage earning for activity 1 on 1st day
# a65 Status Code for activity 2
# a66   Industry Code (NIC) for activity 2
# a67 hours actuallly worked for activity 2 on 1st day
# a68 wage earning for activity 2 on 1st day
# a69   total hours actually worked on 1st day
# a70   hours available for aditional worked on 1st day
# cws     Current Weekly Status (CWS)
# NIC_cws  Industry Code (CWS)
# NCO_cws   Occupation Code (CWS)
# regularwage Earnings For Regular Salarid/Wage Activity
# selfemp     Earnings For Regular Salarid/Wage Activity
# _merge  Matching result from merge
# Quart Quarter
# WPR_cws Worker Participation Ratio (Current Weekly Status (CWS))
# LFPR_cws Labour Force Participation Ratio (Current Weekly Status (CWS))
# NCO_UPSS1   Occupation Code (NCO)
# NCO_cws1 Occupation Code (CWS)
# Age1  Age


mapping = {
    "Quarter": "Quarter",
    "visit": "Visit",
    "Sector": "Sector",
    "State": "State/Ut Code",
    "fsu": "FSU",
    "sample_sg": "Sample Sg/Sb No.",
    "SSSTRM": "Second Stage Stratum No.",
    "hh_no": "Sample Household Number",
    "month_survey": "Month of Survey",
    "hh_size": "Household Size",
    "hh_type": "Household Type",
    "rsn_sub_org_hh": "Reason for Substitution of original household",
    "religion": "Religion",
    "social_group": "Social Group",
    "hh_cons_exp": "Household's Usual Consumer Expenditure In A Month (Rs.)",
    "info_srn": "Informant Serial no.",
    "NSS": "Ns count for sector x stratum x substratum x sub-sample",
    "NSC": "Ns count for sector x stratum x substratum",
    "MULT": "Sub-sample wise Multiplier",
    "No_QR": "Occurrence of State x Sector x Stratum x SubStratum in 4 Quarters",
    "psn": "Person Serial No.",
    "Reltn_to_head": "Relationship To Head",
    "Sex": "Sex",
    "Age": "Age",
    "Marital_status": "Marital_status",
    "GE": "General Education Level",
    "TE": "Technical Education Level",
    "No_yrs_Formal": "No. of years in Formal Education",
    "current_atten": "Status of Current Attendance in Educational Institution",
    "VET": "Whether received any Vocational/Technical Training",
    "Usual_princ": "Status Code",
    "NIC_UPSS": "Industry Code (NIC)",
    "NCO_UPSS": "Occupation Code (NCO)",
    "Sub_act": "Whether Engaged In Any Work In Subsidiary Capacity",
    "Usual_subs": "Status Code",
    "NIC_sub": "Industry Code (NIC)",
    "NCO_sub": "Occupation Code (NCO)",
    "a1": "Status Code for activity 1",
    "a2": "Industry Code (NIC) for activity 1",
    "a3": "hours actually worked for activity 1 on 7th day",
    "a4": "wage earning for activity 1 on 7th day",
    "a5": "Status Code for activity 2",
    "a6": "Industry Code (NIC) for activity 2",
    "a7": "hours actually worked for activity 2 on 7th day",
    "a8": "wage earning for activity 2 on 7th day",
    "a9": "total hours actually worked on 7th day",
    "a10": "hours available for additional work on 7th day",
    "a11": "Status Code for activity 1",
    "a12": "Industry Code (NIC) for activity 1",
    "a13": "hours actually worked for activity 1 on 6th day",
    "a14": "wage earning for activity 1 on 6th day",
    "a15": "Status Code for activity 2",
    "a16": "Industry Code (NIC) for activity 2",
    "a17": "hours actually worked for activity 2 on 6th day",
    "a18": "wage earning for activity 2 on 6th day",
    "a19": "total hours actually worked on 6th day",
    "a20": "hours available for additional work on 6th day",
    "a21": "Status Code for activity 1",
    "a22": "Industry Code (NIC) for activity 1",
    "a23": "hours actually worked for activity 1 on 5th day",
    "a24": "wage earning for activity 1 on 5th day",
    "a25": "Status Code for activity 2",
    "a26": "Industry Code (NIC) for activity 2",
    "a27": "hours actually worked for activity 2 on 5th day",
    "a28": "wage earning for activity 2 on 5th day",
    "a29": "total hours actually worked on 5th day",
    "a30": "hours available for additional work on 5th day",
    "a31": "Status Code for activity 1",
    "a32": "Industry Code (NIC) for activity 1",
    "a33": "hours actually worked for activity 1 on 4th day",
    "a34": "wage earning for activity 1 on 4th day",
    "a35": "Status Code for activity 2",
    "a36": "Industry Code (NIC) for activity 2",
    "a37": "hours actually worked for activity 2 on 4th day",
    "a38": "wage earning for activity 2 on 4th day",
    "a39": "total hours actually worked on 4th day",
    "a40": "hours available for additional work on 4th day",
    "a41": "Status Code for activity 1",
    "a42": "Industry Code (NIC) for activity 1",
    "a43": "hours actually worked for activity 1 on 3rd day",
    "a44": "wage earning for activity 1 on 3rd day",
    "a45": "Status Code for activity 2",
    "a46": "Industry Code (NIC) for activity 2",
    "a47": "hours actually worked for activity 2 on 3rd day",
    "a48": "wage earning for activity 2 on 3rd day",
    "a49": "total hours actually worked on 3rd day",
    "a50": "hours available for additional work on 3rd day",
    "a51": "Status Code for activity 1",
    "a52": "Industry Code (NIC) for activity 1",
    "a53": "hours actually worked for activity 1 on 2nd day",
    "a54": "wage earning for activity 1 on 2nd day",
    "a55": "Status Code for activity 2",
    "a56": "Industry Code (NIC) for activity 2",
    "a57": "hours actually worked for activity 2 on 2nd day",
    "a58": "wage earning for activity 2 on 2nd day",
    "a59": "total hours actually worked on 2nd day",
    "a60": "hours available for additional work on 2nd day",
    "a61": "Status Code for activity 1",
    "a62": "Industry Code (NIC) for activity 1",
    "a63": "hours actually worked for activity 1 on 1st day",
    "a64": "wage earning for activity 1 on 1st day",
    "a65": "Status Code for activity 2",
    "a66": "Industry Code (NIC) for activity 2",
    "a67": "hours actually worked for activity 2 on 1st day",
    "a68": "wage earning for activity 2 on 1st day",
    "a69": "total hours actually worked on 1st day",
    "a70": "hours available for additional work on 1st day",    
    "cws": "Current Weekly Status (CWS)",
    "NIC_cws": "Industry Code (CWS)",
    "NCO_cws": "Occupation Code (CWS)",
    "regularwage": "Earnings For Regular Salaried/Wage Activity",
    "selfemp": "Earnings For Regular Salaried/Wage Activity",
    "_merge": "Matching result from merge",
    "Quart": "Quarter",
    "WPR_cws": "Worker Participation Ratio (CWS)",
    "LFPR_cws": "Labour Force Participation Ratio (CWS)",
    "NCO_UPSS1": "Occupation Code (NCO)",
    "NCO_cws1": "Occupation Code (CWS)",
    "Age1": "Age"
}

df.rename(columns=mapping, inplace=True)
df.head()
# Out:
#   Quarter Visit  Sector  State/Ut Code    FSU  Sample Sg/Sb No.  \
# 0      Q3    V1       1              9  10001                 1
# 1      Q3    V1       1              9  10001                 1
# 2      Q3    V1       1              9  10001                 1
# 3      Q3    V1       1              9  10001                 1
# 4      Q3    V1       1              9  10001                 2
#
#    Second Stage Stratum No.  Sample Household Number  Month of Survey  \
# 0                         1                        1                1
# 1                         2                        1                1
# 2                         2                        2                1
# 3                         3                        1                1
# 4                         1                        1                1
#
#    Household Size  ...  SEXm  SEXt  Worker Participation Ratio (CWS)  UR_cws  \
# 0               3  ...   1.0     1                                 1     0.0
# ...

# %%
# getting the all the columns
l=list(df.columns)
print(l)
# Out:
# ['Quarter', 'Visit', 'Sector', 'State/Ut Code', 'FSU', 'Sample Sg/Sb No.', 'Second Stage Stratum No.', 'Sample Household Number', 'Month of Survey', 'Household Size', 'Household Type', 'Reason for Substitution of original household', 'Religion', 'Social Group', "Household's Usual Consumer Expenditure In A Month (Rs.)", 'Informant Serial no.', 'Ns count for sector x stratum x substratum x sub-sample', 'Ns count for sector x stratum x substratum', 'Sub-sample wise Multiplier', 'Occurrence of State x Sector x Stratum x SubStratum in 4 Quarters', 'weight_hh_fv', 'Person Serial No.', 'Relationship To Head', 'Sex', 'Age', 'Marital_status', 'General Education Level', 'Technical Education Level', 'No_yrs_Formal_Edu', 'current_attendance', 'Whether received any Vocational/Technical Training', 'Status Code', 'Industry Code (NIC)', 'Occupation Code (NCO)', 'Whether Engaged In Any Work In Subsidiary Capacity', 'Status Code', 'Industry Code (NIC)', 'Occupation Code (NCO)', 'Status Code for activi
# ...

# %%
df['Reason for Substitution of original household']
# Out:
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#           ..
# 848032   NaN
# 848033   NaN
# 848034   NaN
# 848035   NaN
# 848036   NaN
# Name: Reason for Substitution of original household, Length: 848037, dtype: float64

# %%
import pandas as pd

# Define mapping dictionaries with integer keys
Month_of_Survey = {1: 'Jan', 2: 'Feb', 3: 'Mar', 4: 'Apr', 5: 'May', 6: 'Jun',
                   7: 'Jul', 8: 'Aug', 9: 'Sep', 10: 'Oct', 11: 'Nov', 12: 'Dec'}
Response_Code = {1: 'co-operative and capable', 2: 'co-operative but not capable',
                 3: 'busy', 4: 'reluctant', 9: 'others'}
Survey_Code = {1: 'original', 2: 'substitute', 3: 'casualty'}
ReasonSubstitutionOrigHH = {1: 'informant busy', 2: 'members away from home',
                            3: 'informant non-cooperative', 9: 'others'}
Religion = {1: 'Hinduism', 2: 'Islam', 3: 'Christianity', 4: 'Sikhism',
            5: 'Jainism', 6: 'Buddhism', 7: 'Zoroastrianism', 9: 'others'}
Social_Group = {1: 'scheduled tribe', 2: 'scheduled caste', 3: 'other backward class', 9: 'others'}
martial_status={1:'never married',2:'currently married',3:'widowed',4:'divorced/separated'}
General_Education_level={
    1:'not literate',2:'EGS/NFEC/AEC',3:'TLC',4:'others',5:'below primary',6:'primary',7:'middle',8:'secondary',10:'higher secondary',12:'graduate',13:'post graduate and above'
}
Techincal_Education_level={1:'no technical education',2:'agriculture',3:'engineering/technology',4:'medicine',5:'crafts',6:'other subjects',7:'agriculture',8:'engineering/technology',9:'medicine',10:'crafts',11:'other subjects',12:'agriculture',13:'engineering/technology',14:'medicine',15:'crafts',16:'other subjects'}
Whether_received_any_Vocational_Technical_Training={1.0:'received formal vocational/technical training',2.0:'hereditary',3.0:'self-learning',4.0:'learning on the job',5.0:'others',6.0:'did not receive any vocational training'}
current_attendance={1:"school too far",2:"to supplement hh. income",3:"education not considered necessary",4:"to attend domestic chores",5:"others",21:"EGS/NFEC/AEC",22:"TLC",23:"pre-primary",24:"middle",25:"secondary",26:"higher secondary",27:"graduate",28:"agriculture",29:"engineering/technology",30:"medicine",31:"crafts",32:"other subjects",33:"agriculture",34:"engineering/technology",35:"medicine",36:"crafts",37:"other subjects",38:"agriculture",39:"engineering/technology",40:"medicine",41:"crafts",42:"other subjects",43:"post graduate and above"}
Whether_Engaged_In_Any_Work_In_Subsidiary_Capacity={1:"yes",2:"no"}
Sex={1:"male",2:"female",3:"transgender"}
Sector={1:"rural",2:"urban"}
relationship_categories = {
    "1": "self",
    "2": "spouse of head",
    "3": "married child",
    "4": "spouse of married child",
    "5": "unmarried child",
    "6": "grandchild",
    "7": "father/mother/father-in-law/mother-in-law",
    "8": "brother/sister/brother-in-law/sister-in-law/other relatives",
    "9": "servants/employees/other non-relatives"
}

# Map integer keys to string values
df['Month of Survey'] = df['Month of Survey'].astype(int).map(Month_of_Survey)
# df['Reason for Substitution of original household'] = df['Reason for Substitution of original household'].astype(int).map(ReasonSubstitutionOrigHH)
df['Religion'] = df['Religion'].astype(int).map(Religion)
df['Social Group'] = df['Social Group'].astype(int).map(Social_Group)
df['Marital_status'] = df['Marital_status'].astype(int).map(martial_status)
df['General Education Level'] = df['General Education Level'].astype(int).map(General_Education_level)
df['Technical Education Level'] = df['Technical Education Level'].astype(int).map(Techincal_Education_level)
# df['Whether received any Vocational/Technical Training'] = df['Whether received any Vocational/Technical Training'].astype(int).map(Whether_received_any_Vocational_Technical_Training)
# df['current_attendance'] = df['current_attendance'].astype(float).map(current_attendance)
df['Whether Engaged In Any Work In Subsidiary Capacity']=df['Whether Engaged In Any Work In Subsidiary Capacity'].astype(int).map(Whether_Engaged_In_Any_Work_In_Subsidiary_Capacity)
df['Sex']=df['Sex'].astype(int).map(Sex)
df['Sector']=df['Sector'].astype(int).map(Sector)
df['Relationship To Head'] = df['Relationship To Head'].astype(str).map(relationship_categories)

df.head()
# Out:
#   Quarter Visit Sector  State/Ut Code    FSU  Sample Sg/Sb No.  \
# 0      Q3    V1  rural              9  10001                 1
# 1      Q3    V1  rural              9  10001                 1
# 2      Q3    V1  rural              9  10001                 1
# 3      Q3    V1  rural              9  10001                 1
# 4      Q3    V1  rural              9  10001                 2
#
#    Second Stage Stratum No.  Sample Household Number Month of Survey  \
# 0                         1                        1             Jan
# 1                         2                        1             Jan
# 2                         2                        2             Jan
# 3                         3                        1             Jan
# 4                         1                        1             Jan
#
#    Household Size  ...  SEXm  SEXt Worker Participation Ratio (CWS) UR_cws  \
# 0               3  ...   1.0     1                                1    0.0
# ...

# %%
df['Social Group']
# Out:
# 0         other backward class
# 1         other backward class
# 2         other backward class
# 3         other backward class
# 4              scheduled caste
#                   ...
# 848032         scheduled caste
# 848033         scheduled caste
# 848034         scheduled caste
# 848035         scheduled caste
# 848036         scheduled caste
# Name: Social Group, Length: 848037, dtype: object

# %%
df['Reason for Substitution of original household']
# Out:
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#           ..
# 848032   NaN
# 848033   NaN
# 848034   NaN
# 848035   NaN
# 848036   NaN
# Name: Reason for Substitution of original household, Length: 848037, dtype: float64

# %%
df['Marital_status'].value_counts()
# Out:
# Marital_status
# currently married     421907
# never married         373252
# widowed                48991
# divorced/separated      3887
# Name: count, dtype: int64

# %%
df['General Education Level'].value_counts()
# Out:
# General Education Level
# not literate               189999
# middle                     160461
# primary                    115396
# secondary                  103611
# below primary               93062
# higher secondary            85785
# graduate                    66028
# post graduate and above     19161
# others                       5133
# EGS/NFEC/AEC                  819
# TLC                            32
# Name: count, dtype: int64

# %%
df['Technical Education Level'].value_counts()
# Out:
# Technical Education Level
# no technical education    823591
# engineering/technology     11024
# other subjects             10545
# medicine                    2410
# agriculture                  253
# crafts                       214
# Name: count, dtype: int64

# %%
df['Whether received any Vocational/Technical Training'].value_counts()
# Out:
# Whether received any Vocational/Technical Training
# 6.0    470361
# 4.0     39704
# 3.0     30416
# 2.0     29380
# 1.0     22610
# 5.0     12357
# Name: count, dtype: int64

# %%
df['current_attendance'].value_counts()
# Out:
# current_attendance
# 24.0    69908
# 5.0     58566
# 12.0    54952
# 25.0    45272
# 14.0    39217
# 26.0    35982
# 15.0    31621
# 27.0    30129
# 31.0    25770
# 23.0    13260
# 13.0     6718
# 32.0     4532
# 29.0     2540
# 1.0      2067
# 4.0       997
# 30.0      886
# 3.0       864
# 34.0      830
# 37.0      777
# 2.0       623
# 43.0      478
# 11.0      410
# 42.0      328
# 28.0      303
# 35.0      289
# 21.0      193
# 39.0      140
# 40.0       94
# 22.0       94
# 36.0       33
# 33.0       16
# 38.0       10
# 41.0        9
# Name: count, dtype: int64

# %%
df['Whether Engaged In Any Work In Subsidiary Capacity'].value_counts()
# Out:
# Whether Engaged In Any Work In Subsidiary Capacity
# no     768834
# yes     79203
# Name: count, dtype: int64

# %%
df['current_attendance'] = df['current_attendance'].astype(float).map(current_attendance)

# %%
df['Whether received any Vocational/Technical Training'] = df['Whether received any Vocational/Technical Training'].fillna(0).astype(int).map(Whether_received_any_Vocational_Technical_Training)

df['Whether received any Vocational/Technical Training'].value_counts()
# Out:
# Whether received any Vocational/Technical Training
# did not receive any vocational training          470361
# learning on the job                               39704
# self-learning                                     30416
# hereditary                                        29380
# received formal vocational/technical training     22610
# others                                            12357
# Name: count, dtype: int64

# %%
df.head()
# Out:
#   Quarter Visit Sector  State/Ut Code    FSU  Sample Sg/Sb No.  \
# 0      Q3    V1  rural              9  10001                 1
# 1      Q3    V1  rural              9  10001                 1
# 2      Q3    V1  rural              9  10001                 1
# 3      Q3    V1  rural              9  10001                 1
# 4      Q3    V1  rural              9  10001                 2
#
#    Second Stage Stratum No.  Sample Household Number Month of Survey  \
# 0                         1                        1             Jan
# 1                         2                        1             Jan
# 2                         2                        2             Jan
# 3                         3                        1             Jan
# 4                         1                        1             Jan
#
#    Household Size  ...  SEXm  SEXt Worker Participation Ratio (CWS) UR_cws  \
# 0               3  ...   1.0     1                                1    0.0
# ...

# %%
# salary getting the salary
df['Earnings For Regular Salaried/Wage Activity']
df['Sector'].value_counts()
# Out:
# Sector
# rural    493146
# urban    354891
# Name: count, dtype: int64

# %%
df['Sex'].value_counts()
# Out:
# Sex
# male           431291
# female         416709
# transgender        37
# Name: count, dtype: int64

# %%
# saving the dataframe
df.to_csv("new_data.csv",index=False)

# %%
df['Household Size'].value_counts()
# Out:
# Household Size
# 4     207724
# 5     191815
# 6     128100
# 3     104721
# 7      66808
# 2      46642
# 8      36880
# 9      20502
# 1      14436
# 10     12390
# 11      6864
# 12      4584
# 13      2353
# 14      1498
# 15      1050
# 16       512
# 17       459
# 18       234
# 20       160
# 19        95
# 21        84
# 29        29
# 28        28
# 24        24
# 23        23
# 22        22
# Name: count, dtype: int64

# %%
df['Household Type'].value_counts()
# Out:
# Household Type
# 1    331416
# 2    248973
# 3    122513
# 5     72153
# 9     38960
# 4     34022
# Name: count, dtype: int64

# %%
# getting the sector
df['Sector'].value_counts()
# Out:
# Sector
# rural    493146
# urban    354891
# Name: count, dtype: int64

# %%
import pandas as pd

r=pd.read_csv("new_data.csv")
r.head()
r['Household Type']
# Out:
# 0         1
# 1         1
# 2         9
# 3         5
# 4         2
#          ..
# 848032    2
# 848033    2
# 848034    2
# 848035    2
# 848036    2
# Name: Household Type, Length: 848037, dtype: int64

# %% [markdown]
# ### Distribution of Estimated HHs across Sector in pie chart

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("new_data.csv")
df.head()

# Distribution of Estimated HHs across Sector in pie chart
plt.figure(figsize=(10, 10))
df['Sector'].value_counts().plot.pie(autopct='%1.1f%%')
plt.title("Distribution of Estimated HHs across Sector")
plt.show()

# %% [markdown]
# #### Distribution of Earnings For Regular Salaried/Wage Activity across Sector

# %%
# Distribution of Earnings For Regular Salaried/Wage Activity across Sector
plt.figure(figsize=(10, 10))
sns.boxplot(x='Sector', y='Earnings For Regular Salaried/Wage Activity', data=df)
plt.title("Distribution of Earnings For Regular Salaried/Wage Activity across Sector")
plt.show()

# %%
# column names
l=list(df.columns)
print(l)
# data types of the columns
re=df.dtypes
print(re)
# Out:
# ['Quarter', 'Visit', 'Sector', 'State/Ut Code', 'FSU', 'Sample Sg/Sb No.', 'Second Stage Stratum No.', 'Sample Household Number', 'Month of Survey', 'Household Size', 'Household Type', 'Reason for Substitution of original household', 'Religion', 'Social Group', "Household's Usual Consumer Expenditure In A Month (Rs.)", 'Informant Serial no.', 'Ns count for sector x stratum x substratum x sub-sample', 'Ns count for sector x stratum x substratum', 'Sub-sample wise Multiplier', 'Occurrence of State x Sector x Stratum x SubStratum in 4 Quarters', 'weight_hh_fv', 'Person Serial No.', 'Relationship To Head', 'Sex', 'Age', 'Marital_status', 'General Education Level', 'Technical Education Level', 'No_yrs_Formal_Edu', 'current_attendance', 'Whether received any Vocational/Technical Training', 'Status Code', 'Industry Code (NIC)', 'Occupation Code (NCO)', 'Whether Engaged In Any Work In Subsidiary Capacity', 'Status Code.1', 'Industry Code (NIC).1', 'Occupation Code (NCO).1', 'Status Code for 
# ...

# %% [markdown]
# ### Analysis-1

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


# General plot style
sns.set(style="whitegrid")
plt.rcParams["figure.figsize"] = (12, 6)

# Helper function for adding titles
def plot_title(ax, title):
    ax.set_title(title, fontsize=14, fontweight='bold')
    ax.set_xlabel(ax.get_xlabel(), fontsize=12)
    ax.set_ylabel(ax.get_ylabel(), fontsize=12)

# 1. Age Distribution

plt.figure()
ax = sns.histplot(data=df, x="Age", bins=20, kde=True, color="skyblue")
plot_title(ax, "Age Distribution Across Sectors")
plt.show()

# 2. Gender Distribution by Sector

plt.figure()
ax = sns.countplot(data=df, x="Sector", hue="Sex", palette="Set2")
plot_title(ax, "Gender Distribution by Sector")
plt.legend(title="Gender")
plt.show()

# 3. Household Size by Sector
plt.figure()
ax = sns.boxplot(data=df, x="Sector", y="Household Size", palette="Set3")
plot_title(ax, "Household Size Distribution by Sector")
plt.show()

# 4. Worker Participation Rate by Sector
plt.figure()
ax = sns.barplot(data=df, x="Sector", y="Worker Participation Ratio (CWS)", ci=None, palette="muted")
plot_title(ax, "Worker Participation Rate by Sector")
plt.show()

# 5. Labor Force Participation Rate by Gender and Sector
plt.figure()
ax = sns.barplot(data=df, x="Sector", y="Labour Force Participation Ratio (CWS)", hue="Sex", ci=None, palette="pastel")
plot_title(ax, "Labour Force Participation Rate by Gender and Sector")
plt.legend(title="Gender")
plt.show()

# 6. Monthly Household Expenditure by Social Group
plt.figure()
ax = sns.boxplot(data=df, x="Social Group", y="Household's Usual Consumer Expenditure In A Month (Rs.)", palette="coolwarm")
plot_title(ax, "Monthly Household Expenditure by Social Group")
plt.xticks(rotation=45)
plt.show()

# 7. Household Expenditure by Sector
plt.figure()
ax = sns.boxplot(data=df, x="Sector", y="Household's Usual Consumer Expenditure In A Month (Rs.)", palette="husl")
plot_title(ax, "Monthly Household Expenditure by Sector")
plt.show()

# 8. Household Expenditure by Household Size
plt.figure()
ax = sns.scatterplot(data=df, x="Household Size", y="Household's Usual Consumer Expenditure In A Month (Rs.)", alpha=0.6)
plot_title(ax, "Household Expenditure by Household Size")
plt.show()

# 9. Temporal Analysis of Worker Participation Rate
plt.figure()
ax = sns.lineplot(data=df, x="Month of Survey", y="Worker Participation Ratio (CWS)", hue="Sector", marker="o", palette="Dark2")
plot_title(ax, "Worker Participation Rate Over Time")
plt.xticks(rotation=45)
plt.show()

# 10. Correlation Between Variables
plt.figure()
corr_cols = [
    "Household Size", 
    "Household's Usual Consumer Expenditure In A Month (Rs.)", 
    "Worker Participation Ratio (CWS)", 
    "Labour Force Participation Ratio (CWS)"
]

correlation_matrix = df[corr_cols].corr()
ax = sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
plot_title(ax, "Correlation Between Key Metrics")
plt.show()

# 11. Gender Disparities in Participation Rate
plt.figure()
ax = sns.boxplot(data=df, x="Sex", y="Worker Participation Ratio (CWS)", palette="viridis")
plot_title(ax, "Gender Disparities in Worker Participation Rate")
plt.show()

# 12. Disparities in Expenditure Across Religions
plt.figure()
ax = sns.boxplot(data=df, x="Religion", y="Household's Usual Consumer Expenditure In A Month (Rs.)", palette="Set1")
plot_title(ax, "Disparities in Expenditure Across Religions")
plt.xticks(rotation=45)
plt.show()

# 13. Outliers in Household Expenditure
plt.figure()
ax = sns.boxplot(data=df, y="Household's Usual Consumer Expenditure In A Month (Rs.)", color="coral")
plot_title(ax, "Outliers in Household Expenditure")
plt.show()
# Out:
# C:\Users\I.V.SRICHANDRA\AppData\Local\Temp\ipykernel_98764\4280598713.py:33: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.boxplot(data=df, x="Sector", y="Household Size", palette="Set3")
# C:\Users\I.V.SRICHANDRA\AppData\Local\Temp\ipykernel_98764\4280598713.py:39: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   ax = sns.barplot(data=df, x="Sector", y="Worker Participation Ratio (CWS)", ci=None, palette="muted")
# C:\Users\I.V.SRICHANDRA\AppData\Local\Temp\ipykernel_98764\4280598713.py:39: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(data=df, x="Sector", y="Worker Participation Ratio (CWS)", ci=None, palette="muted")
# ...

# %% [markdown]
# ### Analysis-2

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# General plot style
sns.set(style="whitegrid")
plt.rcParams["figure.figsize"] = (12, 6)

# Helper function to add titles
def plot_title(ax, title):
    ax.set_title(title, fontsize=14, fontweight='bold')
    ax.set_xlabel(ax.get_xlabel(), fontsize=12)
    ax.set_ylabel(ax.get_ylabel(), fontsize=12)

# ------------------------- Demographic Analysis -------------------------

# 1. Age distribution across sectors
plt.figure()
ax = sns.histplot(data=df, x="Age", hue="Sector", bins=20, kde=True, palette="Set2")
plot_title(ax, "Age Distribution Across Sectors")
plt.show()

# 2. Population distribution by gender, religion, and social group
plt.figure()
ax = sns.countplot(data=df, x="Religion", hue="Sex", palette="muted")
plot_title(ax, "Population Distribution by Gender and Religion")
plt.xticks(rotation=45)
plt.show()

# Gender distribution by social group
plt.figure()
ax = sns.countplot(data=df, x="Social Group", hue="Sex", palette="coolwarm")
plot_title(ax, "Population Distribution by Gender and Social Group")
plt.xticks(rotation=45)
plt.show()

# 3. Average household size by sector and social group
plt.figure()
ax = sns.barplot(data=df, x="Sector", y="Household Size", ci=None, palette="husl")
plot_title(ax, "Average Household Size by Sector")
plt.show()

plt.figure()
ax = sns.barplot(data=df, x="Social Group", y="Household Size", ci=None, palette="coolwarm")
plot_title(ax, "Average Household Size by Social Group")
plt.xticks(rotation=45)
plt.show()

# 4. Marital status breakdown across age groups and genders
plt.figure()
ax = sns.countplot(data=df, x="Marital_status", hue="Sex", palette="Set3")
plot_title(ax, "Marital Status Breakdown by Gender")
plt.xticks(rotation=45)
plt.show()

plt.figure()
ax = sns.boxplot(data=df, x="Marital_status", y="Age", palette="coolwarm")
plot_title(ax, "Marital Status Across Age Groups")
plt.xticks(rotation=45)
plt.show()

# --------------------- Economic Activity Analysis ----------------------

# 5. Worker Participation Rate across sectors
plt.figure()
ax = sns.barplot(data=df, x="Sector", y="Worker Participation Ratio (CWS)", ci=None, palette="pastel")
plot_title(ax, "Worker Participation Rate Across Sectors")
plt.show()

# 6. Labor Force Participation Rate by gender and sector
plt.figure()
ax = sns.barplot(data=df, x="Sector", y="Labour Force Participation Ratio (CWS)", hue="Sex", ci=None, palette="muted")
plot_title(ax, "Labor Force Participation Rate by Gender and Sector")
plt.legend(title="Gender")
plt.show()

# 7. Employment status trends by Quarter and Month of Survey
plt.figure()
ax = sns.lineplot(data=df, x="Quarter", y="Worker Participation Ratio (CWS)", hue="Sector", marker="o", palette="Dark2")
plot_title(ax, "Trends in Worker Participation Rate by Quarter")
plt.show()

plt.figure()
ax = sns.lineplot(data=df, x="Month of Survey", y="Worker Participation Ratio (CWS)", hue="Sector", marker="o", palette="husl")
plot_title(ax, "Trends in Worker Participation Rate by Month")
plt.show()

# 8. Household type and workforce participation correlation
plt.figure()
ax = sns.boxplot(data=df, x="Household Type", y="Worker Participation Ratio (CWS)", palette="coolwarm")
plot_title(ax, "Workforce Participation by Household Type")
plt.xticks(rotation=45)
plt.show()

# --------------------- Household Expenditure Analysis ------------------

# 9. Average household consumption expenditure by sector
plt.figure()
ax = sns.barplot(data=df, x="Sector", y="Household's Usual Consumer Expenditure In A Month (Rs.)", ci=None, palette="pastel")
plot_title(ax, "Average Household Consumption Expenditure by Sector")
plt.show()

# 10. Expenditure by social group and religion
plt.figure()
ax = sns.boxplot(data=df, x="Social Group", y="Household's Usual Consumer Expenditure In A Month (Rs.)", palette="husl")
plot_title(ax, "Household Expenditure by Social Group")
plt.xticks(rotation=45)
plt.show()

plt.figure()
ax = sns.boxplot(data=df, x="Religion", y="Household's Usual Consumer Expenditure In A Month (Rs.)", palette="Set3")
plot_title(ax, "Household Expenditure by Religion")
plt.xticks(rotation=45)
plt.show()

# 11. Expenditure by household size
plt.figure()
ax = sns.scatterplot(data=df, x="Household Size", y="Household's Usual Consumer Expenditure In A Month (Rs.)", alpha=0.6)
plot_title(ax, "Expenditure by Household Size")
plt.show()

# --------------------- Sectoral Comparisons ----------------------------

# 12. Gender distribution in urban vs rural sectors
plt.figure()
ax = sns.countplot(data=df, x="Sector", hue="Sex", palette="coolwarm")
plot_title(ax, "Gender Distribution in Urban vs Rural Sectors")
plt.show()

# 13. WPR and LFPR comparisons across sectors
plt.figure()
ax = sns.barplot(data=df, x="Sector", y="Worker Participation Ratio (CWS)", ci=None, palette="muted")
plot_title(ax, "Worker Participation Rate by Sector")
plt.show()

plt.figure()
ax = sns.barplot(data=df, x="Sector", y="Labour Force Participation Ratio (CWS)", ci=None, palette="Set2")
plot_title(ax, "Labor Force Participation Rate by Sector")
plt.show()

# 14. Trends in consumption expenditure over time
plt.figure()
ax = sns.lineplot(data=df, x="Month of Survey", y="Household's Usual Consumer Expenditure In A Month (Rs.)", hue="Sector", marker="o", palette="coolwarm")
plot_title(ax, "Consumption Expenditure Trends Over Time")
plt.show()

# --------------------- Relationships and Correlations ------------------

# 15. Correlation between variables
plt.figure()
corr_cols = ["Household Size", "Household's Usual Consumer Expenditure In A Month (Rs.)", 
             "Worker Participation Ratio (CWS)", "Labour Force Participation Ratio (CWS)"]
correlation_matrix = df[corr_cols].corr()
ax = sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
plot_title(ax, "Correlation Between Variables")
plt.show()

# --------------------- Disparity Analysis ------------------------------

# 16. Disparities in household expenditure across social groups and religions
plt.figure()
ax = sns.boxplot(data=df, x="Social Group", y="Household's Usual Consumer Expenditure In A Month (Rs.)", palette="viridis")
plot_title(ax, "Expenditure Disparities Across Social Groups")
plt.xticks(rotation=45)
plt.show()

plt.figure()
ax = sns.boxplot(data=df, x="Religion", y="Household's Usual Consumer Expenditure In A Month (Rs.)", palette="coolwarm")
plot_title(ax, "Expenditure Disparities Across Religions")
plt.xticks(rotation=45)
plt.show()

# 17. Gender disparities in WPR and LFPR
plt.figure()
ax = sns.boxplot(data=df, x="Sex", y="Worker Participation Ratio (CWS)", palette="Set1")
plot_title(ax, "Gender Disparities in Worker Participation Rate")
plt.show()

plt.figure()
ax = sns.boxplot(data=df, x="Sex", y="Labour Force Participation Ratio (CWS)", palette="Set2")
plot_title(ax, "Gender Disparities in Labor Force Participation Rate")
plt.show()

# --------------------- Key Insights and Outliers -----------------------

# 18. Outliers in household expenditure
plt.figure()
ax = sns.boxplot(data=df, y="Household's Usual Consumer Expenditure In A Month (Rs.)", color="coral")
plot_title(ax, "Outliers in Household Expenditure")
plt.show()

# 19. Highest and lowest participation in workforce by group
plt.figure()
ax = sns.barplot(data=df, x="Social Group", y="Worker Participation Ratio (CWS)", ci=None, palette="coolwarm")
plot_title(ax, "Workforce Participation by Social Group")
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\I.V.SRICHANDRA\AppData\Local\Temp\ipykernel_98764\935850783.py:38: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   ax = sns.barplot(data=df, x="Sector", y="Household Size", ci=None, palette="husl")
# C:\Users\I.V.SRICHANDRA\AppData\Local\Temp\ipykernel_98764\935850783.py:38: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(data=df, x="Sector", y="Household Size", ci=None, palette="husl")
# C:\Users\I.V.SRICHANDRA\AppData\Local\Temp\ipykernel_98764\935850783.py:43: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   ax = sns.barplot(data=df, x="Social Group", y="Household Size", ci=None, palette="coolwarm")
# C:\Users\I.V.SRICHANDRA\AppData\Local\Temp\ipykernel_98764\935850783.py:43: FutureWarning:
#
# ...

# %% [markdown]
# ### Analysis-3

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming 'Status Code' represents employment status and 'Sex' represents gender
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='Status Code', hue='Sex', palette='Set1')

# Add titles and labels
plt.title('Distribution of Employment Status by Sex')
plt.xlabel('Employment Status')
plt.ylabel('Count')
plt.xticks(rotation=45)

plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='Sector', hue='General Education Level', palette='Set2')

# Add titles and labels
plt.title('Sector-wise General Education Level')
plt.xlabel('Sector')
plt.ylabel('Count')
plt.xticks(rotation=45)

plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='General Education Level', hue='Sex', palette='Set2')

# Add titles and labels
plt.title('Gender-wise General Education Level')
plt.xlabel('General Education Level')
plt.ylabel('Count')
plt.xticks(rotation=45)

plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='Sector', hue='Technical Education Level', palette='Set2')

# Add titles and labels
plt.title('Sector-wise Technical Education Level')
plt.xlabel('Sector')
plt.ylabel('Count')
plt.xticks(rotation=45)

plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='Technical Education Level', hue='Sex', palette='Set2')

# Add titles and labels
plt.title('Gender-wise Technical Education Level')
plt.xlabel('Technical Education Level')
plt.ylabel('Count')
plt.xticks(rotation=45)

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming df is the DataFrame and it contains the 'Sex' and 'General Education Level' columns
plt.figure(figsize=(10, 6))

# Creating a count plot for Sex vs General Education Level
sns.countplot(data=df, x='General Education Level', hue='Sex')

# Customizing the plot
plt.title('Gender-wise General Education Level')
plt.xlabel('General Education Level')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')
plt.legend(title='Sex')
plt.tight_layout()

# Show the plot
plt.show()

# %%
# work participation rate based on sex
plt.figure(figsize=(10, 6))
sns.barplot(data=df, x='Sex', y='Worker Participation Ratio (CWS)', ci=None, palette='Set2')

# Add titles and labels
plt.title('Worker Participation Rate based on Sex')
plt.xlabel('Sex')
plt.ylabel('Worker Participation Rate')
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\I.V.SRICHANDRA\AppData\Local\Temp\ipykernel_107500\3966330875.py:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=df, x='Sex', y='Worker Participation Ratio (CWS)', ci=None, palette='Set2')
# C:\Users\I.V.SRICHANDRA\AppData\Local\Temp\ipykernel_107500\3966330875.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df, x='Sex', y='Worker Participation Ratio (CWS)', ci=None, palette='Set2')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df=pd.read_csv("new_data.csv")
df.head()
# Out:
#   Quarter Visit Sector  State/Ut Code    FSU  Sample Sg/Sb No.  \
# 0      Q3    V1  rural              9  10001                 1
# 1      Q3    V1  rural              9  10001                 1
# 2      Q3    V1  rural              9  10001                 1
# 3      Q3    V1  rural              9  10001                 1
# 4      Q3    V1  rural              9  10001                 2
#
#    Second Stage Stratum No.  Sample Household Number Month of Survey  \
# 0                         1                        1             Jan
# 1                         2                        1             Jan
# 2                         2                        2             Jan
# 3                         3                        1             Jan
# 4                         1                        1             Jan
#
#    Household Size  ...  SEXm  SEXt Worker Participation Ratio (CWS) UR_cws  \
# 0               3  ...   1.0     1                                1    0.0
# ...

# %%
# column names
l=list(df.columns)
print(l)
# Out:
# ['Quarter', 'Visit', 'Sector', 'State/Ut Code', 'FSU', 'Sample Sg/Sb No.', 'Second Stage Stratum No.', 'Sample Household Number', 'Month of Survey', 'Household Size', 'Household Type', 'Reason for Substitution of original household', 'Religion', 'Social Group', "Household's Usual Consumer Expenditure In A Month (Rs.)", 'Informant Serial no.', 'Ns count for sector x stratum x substratum x sub-sample', 'Ns count for sector x stratum x substratum', 'Sub-sample wise Multiplier', 'Occurrence of State x Sector x Stratum x SubStratum in 4 Quarters', 'weight_hh_fv', 'Person Serial No.', 'Relationship To Head', 'Sex', 'Age', 'Marital_status', 'General Education Level', 'Technical Education Level', 'No_yrs_Formal_Edu', 'current_attendance', 'Whether received any Vocational/Technical Training', 'Status Code', 'Industry Code (NIC)', 'Occupation Code (NCO)', 'Whether Engaged In Any Work In Subsidiary Capacity', 'Status Code.1', 'Industry Code (NIC).1', 'Occupation Code (NCO).1', 'Status Code for 
# ...

# %%
# identifying which sector women were employed
#COPILOT
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='Sector', hue='Sex', palette='Set1')

# Add titles and labels
plt.title('Distribution of Employment by Sector and Gender')
plt.xlabel('Sector')
plt.ylabel('Count')
plt.xticks(rotation=45)

plt.show()

# %%
# different type of works exists in the sectors and how many women are employed in each sector

diff_works=df['Industry Code (CWS)'].value_counts()

print(diff_works)
# Out:
# Industry Code (CWS)
# 1.0     112887
# 47.0     34577
# 41.0     29392
# 49.0     14755
# 85.0     13483
#          ...
# 91.0        64
# 9.0         42
# 6.0         32
# 39.0        29
# 99.0         3
# Name: count, Length: 87, dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df=pd.read_csv("new_data.csv")
df.head()

# getting the industry code
df['Industry Code (CWS)'].value_counts()
# Out:
# Industry Code (CWS)
# 1.0     112887
# 47.0     34577
# 41.0     29392
# 49.0     14755
# 85.0     13483
#          ...
# 91.0        64
# 9.0         42
# 6.0         32
# 39.0        29
# 99.0         3
# Name: count, Length: 87, dtype: int64

# %%
import pandas as pd
import numpy as np

# Sample data similar to your dataset
data = {
    'Industry Code (CWS)': [
        1., np.nan, 52., 41., 47., 13., 56., 82., 16., 97., 14., 49., 74.,
        43., 85., 94., 64., 95., 84., 35., 31., 86., 25., 23., 8., 92.,
        87., 2., 24., 55., 46., 75., 10., 90., 53., 3., 12., 20., 60.,
        96., 42., 45., 61., 33., 66., 50., 5., 22., 77., 80., 29., 7.,
        32., 6., 21., 11., 88., 18., 17., 71., 27., 38., 81., 93., 9.,
        62., 63., 36., 15., 28., 78., 19., 37., 79., 69., 26., 68., 65.,
        59., 30., 91., 58., 70., 51., 72., 73., 39., 99.
    ]
}

# Create DataFrame
df = pd.DataFrame(data)

# Dictionary mapping NIC codes to descriptions
industry_codes = {
    1: "Crop and animal production, hunting and related service activities",
    2: "Forestry and logging",
    3: "Fishing and aquaculture",
    5: "Mining of coal and lignite",
    6: "Extraction of crude petroleum and natural gas",
    7: "Mining of metal ores",
    8: "Other mining and quarrying",
    9: "Mining support service activities",
    10: "Manufacture of food products",
    11: "Manufacture of beverages",
    12: "Manufacture of tobacco products",
    13: "Manufacture of textiles",
    14: "Manufacture of wearing apparel",
    15: "Manufacture of leather and related products",
    16: "Manufacture of wood and wood products, excluding furniture",
    17: "Manufacture of paper and paper products",
    18: "Printing and reproduction of recorded media",
    19: "Manufacture of coke and refined petroleum products",
    20: "Manufacture of chemicals and chemical products",
    21: "Manufacture of pharmaceuticals and medicinal products",
    22: "Manufacture of rubber and plastic products",
    23: "Manufacture of non-metallic mineral products",
    24: "Manufacture of basic metals",
    25: "Manufacture of fabricated metal products",
    26: "Manufacture of computer, electronic, and optical products",
    27: "Manufacture of electrical equipment",
    28: "Manufacture of machinery and equipment",
    29: "Manufacture of motor vehicles",
    30: "Manufacture of other transport equipment",
    31: "Manufacture of furniture",
    32: "Other manufacturing",
    33: "Repair and installation of machinery and equipment",
    35: "Electricity, gas, steam, and air conditioning supply",
    36: "Water collection, treatment, and supply",
    37: "Sewerage",
    38: "Waste management and remediation activities",
    39: "Remediation and other waste management services",
    41: "Construction of buildings",
    42: "Civil engineering",
    43: "Specialized construction activities",
    45: "Wholesale and retail trade of motor vehicles and motorcycles",
    46: "Wholesale trade except motor vehicles and motorcycles",
    47: "Retail trade except motor vehicles and motorcycles",
    49: "Land transport and transport via pipelines",
    50: "Water transport",
    51: "Air transport",
    52: "Warehousing and support activities for transportation",
    53: "Postal and courier activities",
    55: "Accommodation",
    56: "Food and beverage service activities",
    58: "Publishing activities",
    59: "Motion picture, video and television programme production, sound recording and music publishing activities",
    60: "Programming and broadcasting activities",
    61: "Telecommunications",
    62: "Computer programming, consultancy and related activities",
    63: "Information service activities",
    64: "Financial service activities, except insurance and pension funding",
    65: "Insurance, reinsurance and pension funding, except compulsory social security",
    66: "Activities auxiliary to financial service and insurance activities",
    68: "Real estate activities",
    69: "Legal and accounting activities",
    70: "Activities of head offices; management consultancy activities",
    71: "Architecture and engineering activities; technical testing and analysis",
    72: "Scientific research and development",
    73: "Advertising and market research",
    74: "Other professional, scientific and technical activities",
    75: "Veterinary activities",
    77: "Rental and leasing activities",
    78: "Employment activities",
    79: "Travel agency, tour operator and other reservation service activities",
    80: "Security and investigation activities",
    81: "Services to buildings and landscape activities",
    82: "Office administrative, office support and other business support activities",
    84: "Public administration and defence; compulsory social security",
    85: "Education",
    86: "Human health activities",
    87: "Residential care activities",
    88: "Social work activities without accommodation",
    90: "Creative, arts and entertainment activities",
    91: "Libraries, archives, museums and other cultural activities",
    92: "Gambling and betting activities",
    93: "Sports activities and amusement and recreation activities",
    94: "Activities of membership organizations",
    95: "Repair of computers and personal and household goods",
    96: "Other personal service activities",
    97: "Activities of households as employers of domestic personnel",
    99: "Activities of extraterritorial organizations and bodies"
}

# Replace codes in the DataFrame with their descriptions
df['Industry Description'] = df['Industry Code (CWS)'].map(industry_codes)

# Display the updated DataFrame
print(df)

# Handle NaN values (optional)
df['Industry Description'].fillna('Unknown or Missing Code', inplace=True)

# Display unique codes and their descriptions
unique_codes = df.drop_duplicates(subset='Industry Code (CWS)')[['Industry Code (CWS)', 'Industry Description']]
print(unique_codes)
# Out:
#     Industry Code (CWS)                               Industry Description
# 0                   1.0  Crop and animal production, hunting and relate...
# 1                   NaN                                                NaN
# 2                  52.0  Warehousing and support activities for transpo...
# 3                  41.0                          Construction of buildings
# 4                  47.0  Retail trade except motor vehicles and motorcy...
# ..                  ...                                                ...
# 83                 51.0                                      Air transport
# 84                 72.0                Scientific research and development
# 85                 73.0                    Advertising and market research
# 86                 39.0    Remediation and other waste management services
# 87                 99.0  Activities of extraterritorial organizations a...
#
# [88 rows x 2 columns]
# ...

# %% [markdown]
# ### evaluation02

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# Load the dataset
df = pd.read_csv("new_data.csv")

# Head of the dataset to verify the loaded data
print(df.head())

# ======= 1. Distribution of 'Industry Code (CWS)' =======
plt.figure(figsize=(12, 6))
sns.countplot(data=df, x='Industry Code (CWS)', palette='viridis', order=df['Industry Code (CWS)'].value_counts().index)
plt.title("Distribution of Industry Codes (CWS)", fontsize=16)
plt.xlabel("Industry Code (CWS)", fontsize=12)
plt.ylabel("Count", fontsize=12)
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# ======= 2. Worker Participation Ratio by Sector =======
plt.figure(figsize=(10, 6))
sns.boxplot(data=df, x='Sector', y='Worker Participation Ratio (CWS)', palette='coolwarm')
plt.title("Worker Participation Ratio by Sector", fontsize=16)
plt.xlabel("Sector", fontsize=12)
plt.ylabel("Worker Participation Ratio (CWS)", fontsize=12)
plt.tight_layout()
plt.show()

# ======= 3. Labour Force Participation Ratio by State =======
plt.figure(figsize=(15, 8))
sns.barplot(data=df, x='State/Ut Code', y='Labour Force Participation Ratio (CWS)', palette='mako')
plt.title("Labour Force Participation Ratio by State", fontsize=16)
plt.xlabel("State/UT Code", fontsize=12)
plt.ylabel("Labour Force Participation Ratio (CWS)", fontsize=12)
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# ======= 4. Employment Trends Across Sectors =======
sector_trends = df.groupby(['Sector', 'Quarter']).size().unstack()
sector_trends.plot(kind='bar', stacked=True, figsize=(14, 7), colormap='Set3')
plt.title("Employment Trends Across Sectors by Quarter", fontsize=16)
plt.xlabel("Sector", fontsize=12)
plt.ylabel("Number of Observations", fontsize=12)
plt.tight_layout()
plt.show()

# ======= 5. Distribution of Vocational/Technical Training =======
plt.figure(figsize=(8, 5))
training_counts = df['Whether received any Vocational/Technical Training'].value_counts(normalize=True)
plt.figure(figsize=(8, 5))
training_counts = df['Whether received any Vocational/Technical Training'].value_counts(normalize=True)

# Ensure 'explode' matches the number of unique values
explode_values = [0.1 if i == 0 else 0 for i in range(len(training_counts))]

training_counts.plot(kind='pie', autopct='%1.1f%%', colors=['#66c2a5', '#fc8d62'], startangle=90, explode=explode_values)
plt.title("Distribution of Vocational/Technical Training", fontsize=16)
plt.ylabel('')
plt.show()


# ======= 6. Age Distribution of Workers =======
plt.figure(figsize=(12, 6))
sns.histplot(data=df, x='Age', kde=True, bins=30, color='dodgerblue')
plt.title("Age Distribution of Workers", fontsize=16)
plt.xlabel("Age", fontsize=12)
plt.ylabel("Frequency", fontsize=12)
plt.tight_layout()
plt.show()

# ======= 7. Gender Analysis: Participation Ratio =======
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='Sex', y='Worker Participation Ratio (CWS)', palette='pastel')
plt.title("Worker Participation Ratio by Gender", fontsize=16)
plt.xlabel("Gender", fontsize=12)
plt.ylabel("Worker Participation Ratio (CWS)", fontsize=12)
plt.tight_layout()
plt.show()

# ======= 8. Monthly Household Expenditure Analysis =======
plt.figure(figsize=(10, 5))
sns.histplot(data=df, x="Household's Usual Consumer Expenditure In A Month (Rs.)", kde=True, color='coral', bins=40)
plt.title("Household's Usual Consumer Expenditure Distribution", fontsize=16)
plt.xlabel("Monthly Expenditure (Rs.)", fontsize=12)
plt.ylabel("Frequency", fontsize=12)
plt.tight_layout()
plt.show()

# ======= 9. Skill Mapping Insights: Key Sectors =======
plt.figure(figsize=(12, 6))
sns.countplot(data=df, x='Industry Code (CWS)', order=df['Industry Code (CWS)'].value_counts().index[:10], palette='viridis')
plt.title("Top 10 Industry Codes by Frequency", fontsize=16)
plt.xlabel("Industry Code (CWS)", fontsize=12)
plt.ylabel("Count", fontsize=12)
plt.tight_layout()
plt.show()

# ======= 10. Interactive Visualization for Sector vs Labour Force Participation =======
fig = px.scatter(df, x='Sector', y='Labour Force Participation Ratio (CWS)', color='State/Ut Code',
                 title="Interactive Visualization: Sector vs Labour Force Participation",
                 size='Worker Participation Ratio (CWS)', hover_data=['State/Ut Code'])
fig.show()
# Out:
#   Quarter Visit Sector  State/Ut Code    FSU  Sample Sg/Sb No.  \
# 0      Q3    V1  rural              9  10001                 1
# 1      Q3    V1  rural              9  10001                 1
# 2      Q3    V1  rural              9  10001                 1
# 3      Q3    V1  rural              9  10001                 1
# 4      Q3    V1  rural              9  10001                 2
#
#    Second Stage Stratum No.  Sample Household Number Month of Survey  \
# 0                         1                        1             Jan
# 1                         2                        1             Jan
# 2                         2                        2             Jan
# 3                         3                        1             Jan
# 4                         1                        1             Jan
#
#    Household Size  ...  SEXm  SEXt Worker Participation Ratio (CWS) UR_cws  \
# 0               3  ...   1.0     1                                1    0.0
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# Load the dataset (replace with actual file path and column names)
df = pd.read_csv("new_data.csv")


# ===================== 1. LFPR by Social Groups and Regions =====================
plt.figure(figsize=(12, 6))
sns.boxplot(data=df, x='Social Group', y='Labour Force Participation Ratio (CWS)', palette='viridis')
plt.title("Labour Force Participation Ratio by Social Group", fontsize=16)
plt.xlabel("Social Group", fontsize=12)
plt.ylabel("Labour Force Participation Ratio (CWS)", fontsize=12)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\I.V.SRICHANDRA\AppData\Local\Temp\ipykernel_30664\614837662.py:12: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
